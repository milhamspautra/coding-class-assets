# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data=pd.read_csv('../coding-class-assets/Sanitasi Layak 2020.csv',index_col=False)
# Out:
# /tmp/ipykernel_2552/3559640952.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data=pd.read_csv('../coding-class-assets/Sanitasi Layak 2020.csv',index_col=False)

# %%
import os
os.getcwd()
# Out:
# '/home/ilham/belajar.coding/coding-class-assets'

# %%
data.head(10)
# Out:
#    Kd_Prov                   Provinsi  Persentase
# 0       11                       Aceh          77
# 1       12             Sumatera Utara          81
# 2       13             Sumatera Barat          68
# 3       14                       Riau          83
# 4       15                      Jambi          77
# 5       16           Sumatera Selatan          76
# 6       17                   Bengkulu          78
# 7       18                    Lampung          78
# 8       19  Kepulauan Bangka Belitung          92
# 9       21             Kepulauan Riau          89

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Kd_Prov     34 non-null     int64
#  1   Provinsi    34 non-null     object
#  2   Persentase  34 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 944.0+ bytes

# %%
data.shape
# Out:
# (34, 3)

# %%
data.isnull()
# Out:
#     Kd_Prov  Provinsi  Persentase
# 0     False     False       False
# 1     False     False       False
# 2     False     False       False
# 3     False     False       False
# 4     False     False       False
# 5     False     False       False
# 6     False     False       False
# 7     False     False       False
# 8     False     False       False
# 9     False     False       False
# 10    False     False       False
# 11    False     False       False
# 12    False     False       False
# 13    False     False       False
# 14    False     False       False
# 15    False     False       False
# 16    False     False       False
# 17    False     False       False
# 18    False     False       False
# 19    False     False       False
# 20    False     False       False
# 21    False     False       False
# 22    False     False       False
# 23    False     False       False
# 24    False     False       False
# 25    False     False       False
# ...

# %%
data.iloc[21]
# Out:
# Kd_Prov                       63
# Provinsi      Kalimantan Selatan
# Persentase                    81
# Name: 21, dtype: object

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# dtype: bool

# %%
dna=data.dropna()

# %%
dna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Kd_Prov     34 non-null     int64
#  1   Provinsi    34 non-null     object
#  2   Persentase  34 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 944.0+ bytes

# %%
data.loc[data['Persentase'] > 80]
# Out:
#     Kd_Prov                   Provinsi  Persentase
# 1        12             Sumatera Utara          81
# 3        14                       Riau          83
# 8        19  Kepulauan Bangka Belitung          92
# 9        21             Kepulauan Riau          89
# 10       31                DKI Jakarta          93
# 12       33                Jawa Tengah          83
# 13       34            D.I. Yogyakarta          96
# 15       36                     Banten          82
# 16       51                       Bali          95
# 17       52        Nusa Tenggara Barat          82
# 21       63         Kalimantan Selatan          81
# 22       64           Kalimantan Timur          89
# 23       65           Kalimantan Utara          82
# 24       71             Sulawesi Utara          85
# 26       73           Sulawesi Selatan          88
# 27       74          Sulawesi Tenggara          82

# %%
data.loc[data['Persentase'] > 80].loc[data['Persentase'] < 90]
# Out:
#     Kd_Prov             Provinsi  Persentase
# 1        12       Sumatera Utara          81
# 3        14                 Riau          83
# 9        21       Kepulauan Riau          89
# 12       33          Jawa Tengah          83
# 15       36               Banten          82
# 17       52  Nusa Tenggara Barat          82
# 21       63   Kalimantan Selatan          81
# 22       64     Kalimantan Timur          89
# 23       65     Kalimantan Utara          82
# 24       71       Sulawesi Utara          85
# 26       73     Sulawesi Selatan          88
# 27       74    Sulawesi Tenggara          82

# %%
data.plot(kind = 'line', x = 'Provinsi', y = 'Persentase')
plt.title('data sanitasi layak')
plt.xlabel('Provinsi')
# Out:
# Text(0.5, 0, 'Provinsi')

# %%
sns.barplot(data=data, x='Persentase', y='Provinsi', hue='Persentase', legend='auto')
plt.title('data sanitasi layak')
# Out:
# Text(0.5, 1.0, 'data sanitasi layak')
